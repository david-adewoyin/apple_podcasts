# %%
import pandas as pd

# %%
reviews_df= pd.read_csv("https://media.githubusercontent.com/media/david-adewoyin/apple_podcasts/main/dataset/user_reviews.csv",
                names=['id','podcast_id','username','review_title','review','rating','date'])
podcast_df = pd.read_csv("https://raw.githubusercontent.com/david-adewoyin/apple_podcasts/main/dataset/podcasts.csv",
                         names=['id','name','url','studio','category','episode_count','avg_rating','total_ratings','description'])

# %%
reviews_df.head()
# Out:
#    id    podcast_id             username  \
# 0   1  id1647910854             bogwalks
# 1   2  id1647910854            BlueIowan
# 2   3  id1647910854      Pandora's Abyss
# 3   4  id1647910854             TMittels
# 4   5  id1647910854  Kristos Paras Kever
#
#                                    title  \
# 0                                DEJa Vu
# 1                 …and the past repeats…
# 2  Thank you for bringing this to light!
# 3                          Ultra Podcast
# 4                          I love Rachel
#
#                                               review  rating        date
# 0  It’s so amazing that this is deja vu. The stor...       5  2022-10-28
# 1  What a dizzying ride into the past as well as ...       5  2022-10-28
# 2  I say this has happened and people look at me ...       5  2022-10-28
# 3  Crazy how history is repeating itself- just ch...       5  2022-10-28
# 4  But you can’t be wrong that many times and rem...       1  2022-10-28

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542285 entries, 0 to 542284
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            542285 non-null  int64
#  1   podcast_id    542285 non-null  object
#  2   username      542285 non-null  object
#  3   review_title  542280 non-null  object
#  4   review        542282 non-null  object
#  5   rating        542285 non-null  int64
#  6   date          542285 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 29.0+ MB

# %%
podcast_df.head()
# Out:
#              id                           name  \
# 0  id1647910854  Rachel Maddow Presents: Ultra
# 1  id1464919521                   Dateline NBC
# 2  id1200361736                      The Daily
# 3  id1322200189                   Crime Junkie
# 4  id1379959217                         Morbid
#
#                                                  url              studio  \
# 0  https://podcasts.apple.com/us/podcast/rachel-m...               MSNBC
# 1  https://podcasts.apple.com/us/podcast/dateline...        Dateline NBC
# 2  https://podcasts.apple.com/us/podcast/the-dail...  The New York Times
# 3  https://podcasts.apple.com/us/podcast/crime-ju...          audiochuck
# 4  https://podcasts.apple.com/us/podcast/morbid/i...             Wondery
#
#      category  episode_count  avg_rating  total_ratings  \
# 0        News              5         4.8          14900
# 1  True Crime            456         4.5          29000
# 2        News           1669         4.4          88100
# ...

# %%
podcast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2363 non-null   object
#  1   name           2363 non-null   object
#  2   url            2363 non-null   object
#  3   studio         924 non-null    object
#  4   category       2363 non-null   object
#  5   episode_count  2363 non-null   int64
#  6   avg_rating     2363 non-null   float64
#  7   total_ratings  2363 non-null   int64
#  8   description    2363 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 166.3+ KB
